# %% [markdown]
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>Day 34- Seaborn </b></div>

# %% [markdown]
# # Visualize Distributions With Seaborn

# %% [markdown]
# **Seaborn is a library that uses Matplotlib underneath to plot graphs. It will be used to visualize random distributions.**

# %% [markdown]
# ![sns1.png](attachment:sns1.png)

# %% [markdown]
# ### Install Seaborn.

# %% [markdown]
# * If you have Python and PIP already installed on a system, install it using this command:

# %% [raw]
# C:\Users\Your Name>pip install seaborn

# %% [markdown]
# * If you use Jupyter, install Seaborn using this command:

# %% [raw]
# C:\Users\Your Name>!pip install seaborn

# %% [markdown]
# ## Distplots
# **Distplot stands for distribution plot, it takes as input an array and plots a curve corresponding to the distribution of points in the array.**

# %% [markdown]
# ### Import Matplotlib
# **Import the pyplot object of the Matplotlib module in your code using the following statement:**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import Seaborn
# * Import the Seaborn module in your code using the following statement:

# %%
import seaborn as sns

# %% [markdown]
# ## Plotting a Distplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 2, 4, 6, 8, 10])

plt.show()
# Out:
# C:\Users\ST\AppData\Local\Temp\ipykernel_1364\3335008998.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 2, 4, 6, 8, 10])

# %% [markdown]
# ## Plotting a Distplot Without the Histogram

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

plt.show()
# Out:
# C:\Users\ST\AppData\Local\Temp\ipykernel_1364\2406393504.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5], hist=False)
